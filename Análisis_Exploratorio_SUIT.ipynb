# %% [markdown]
# <a href="https://colab.research.google.com/github/ingcarlosleon/Anaisis_Exploratorios_Datos/blob/main/An%C3%A1lisis_Exploratorio_SUIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Análisis exploratorio de los datos del SUIT**
#
# Para este análisis se realizó con la fuente de datos del SUIT **con cohorte al 30-06-2025 entregado por el DAFP**, adicionalmente se uso un comprobador avanzado de disponibilidad de URL, el cual comprueba la disponibilidad de los enlaces web con manejo integral de errores, lógica de reintento y seguimiento del progreso.
#
# Fuente: https://github.com/Ap6pack/advanced-url-checker
#
# Se consideraron variables del conjunto de datos para realizar este análisis exploratorio cómo:
# - **Estado trámite**: ELIMINADO, PUBLICADO, CANCELADO,SIN_GESTION, EN_CORRECCION_CREA, EN_CREACION,EN_REVISION_INSTI
# - **URL_TRAMITE_EN_LINEA**: Almacena URL
# - **Costo total**: Almacena el costo del tramite

# %% [markdown]
# ###**✅ 1. Clonar el repositorio y entrar en la carpeta**

# %%
# !git clone https://github.com/Ap6pack/advanced-url-checker.git
# %cd advanced-url-checker
# Out:
# Cloning into 'advanced-url-checker'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 35 (delta 12), reused 33 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 30.79 KiB | 563.00 KiB/s, done.
# Resolving deltas: 100% (12/12), done.
# /content/advanced-url-checker/advanced-url-checker

# %% [markdown]
# ###**✅ 2. Instalar dependencias**

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: validators>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.35.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: colorama>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->-r requirements.txt (line 1)) (2025.7.14)

# %% [markdown]
# ###**✅ 3. Crear carpeta log para evitar error**

# %%
import os
os.makedirs("/content/advanced-url-checker/log", exist_ok=True)

# %% [markdown]
# ###**✅ 4. Subir y procesar el archivo Excel**
# *  Se carga el archivo **2025_06_30_Base_SUIT.xlsx** al repositorio "Archivos" en Google Drive, simplemente arrastrandolo desde el directorio en donde este alojado
# *  Se Leen las URLs válidas (sin eliminar duplicados)!
#
# ![Archivos.png](data:image/png;base64,...)

# %%
import pandas as pd

# ✅ Leer el archivo desde la raíz de Colab
df = pd.read_excel("/content/2025_06_30_Base_SUIT.xlsx")

# %% [markdown]
# #### Mostrar todos los tramites por Estado trámite

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Contar cuántos trámites hay por estado
estado_counts = df['Estado trámite'].value_counts().reset_index()
estado_counts.columns = ['Estado trámite', 'Conteo']

# Ordenar de mayor a menor
estado_counts_sorted = estado_counts.sort_values(by='Conteo', ascending=False)

# Crear gráfico de barras horizontal
plt.figure(figsize=(8, 4))
ax = sns.barplot(x='Conteo', y='Estado trámite', data=estado_counts_sorted, palette='viridis')

# Agregar etiquetas de cantidad sobre cada barra
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=3)

# Configurar etiquetas del gráfico
plt.xlabel('Conteo')
plt.ylabel('Estado del Trámite')
plt.title('Distribución de Trámites por Estado')
plt.tight_layout()
plt.show()

# %%
# Filter the DataFrame to keep only rows where 'Estado trámite' is 'PUBLICADO'
df = df[df['Estado trámite'] == 'PUBLICADO'].copy()

# Display the first few rows of the filtered DataFrame
display(df.head())

# Print the number of rows in the filtered DataFrame
print(f"Número de trámites con estado 'PUBLICADO': {df.shape[0]}")
# Out:
#    Código SIGEP                    Nombre de la entidad     Orden  \
# 0          8000  ADMINISTRADORA COLOMBIANA DE PENSIONES  NACIONAL
# 1          8000  ADMINISTRADORA COLOMBIANA DE PENSIONES  NACIONAL
# 2          8000  ADMINISTRADORA COLOMBIANA DE PENSIONES  NACIONAL
# 3          8000  ADMINISTRADORA COLOMBIANA DE PENSIONES  NACIONAL
# 6          8000  ADMINISTRADORA COLOMBIANA DE PENSIONES  NACIONAL
#
#                               Naturaleza jurídica   Sector Departamento  \
# 0  Empresas Industriales y Comerciales del Estado  TRABAJO   Bogotá D.C
# 1  Empresas Industriales y Comerciales del Estado  TRABAJO   Bogotá D.C
# 2  Empresas Industriales y Comerciales del Estado  TRABAJO   Bogotá D.C
# 3  Empresas Industriales y Comerciales del Estado  TRABAJO   Bogotá D.C
# 6  Empresas Industriales y Comerciales del Estado  TRABAJO   Bogotá D.C
#
#   Municipio  Categoría  Id interno  Número trámite  ... Numero de documentos  \
# 0    BOGOTÁ  No Aplica      238915            10.0  ...                   13
# 1    BOGOTÁ  No Aplica      238916            12.0  ...                    6
# 2    BOGOTÁ  No Aplica      238918            15.0  ...                    9
# 3    BOGOTÁ  No Aplica      224754          1126.0  ...                    4
# 6    BOGOTÁ  No Aplica      246412         35926.0  ...                   12
#
#   Numero de formularios Tiene costo Costo total       Medio  \
# 0                     1          No         0.0  TOTALMENTE
# 1                     1          No         0.0  TOTALMENTE
# 2                     1          No         0.0  TOTALMENTE
# 3                     3          No         0.0  TOTALMENTE
# 6                     3          No         0.0  TOTALMENTE
#
#                                       PRODUCTO_FINAL Tiempo de obtención  \
# 0   Carta de confirmación de actualización de datos         15 DIA HABIL
# 1  Cuando este se realiza de manera electrónica l...        15 DIA HABIL
# 2                           Respuesta de bienvenida     8 DIA CALENDARIO
# 3  Dictamen o resultado por parte de Colpensiones...              4 MES
# 6           Historia laboral actualizada y corregida        60 DIA HABIL
#
#                                  Obs_tiemp_obtención  \
# 0  El cambio se hace efectivo una vez se validen ...
# 1  Para realizar el tramite  a traves del  portal...
# 2  Si el proceso se realiza de forma electrónica ...
# 3  El término se postergará cuando se soliciten d...
# 6  Para actualización de tiempos públicos se tien...
#
#                                      Medio resultado  \
# 0          Correo certificado,Presencial,Página web,
# 1          Correo certificado,Presencial,Página web,
# 2  Correo electrónico,Correo certificado,Presenci...
# 3                     Correo electrónico,Presencial,
# 6  Correo electrónico,Correo certificado,Correo n...
#
#                                           Dirigido a
# 0                              Ciudadano,Extranjeros
# 1  Instituciones o dependencias públicas,Ciudadan...
# 2                              Ciudadano,Extranjeros
# 3                                         Ciudadano,
# 6                              Ciudadano,Extranjeros
#
# [5 rows x 32 columns]
# Número de trámites con estado 'PUBLICADO': 80044

# %%
# Calculate the number of missing values for each column in the filtered df
missing_values = df.isnull().sum() + (df == "").sum() # Count both NaN and empty strings

# Filter for columns with missing values and sort in descending order
top_missing_values = missing_values[missing_values > 0].sort_values(ascending=False)

# Get the top 10 columns with the most missing values
top_10_missing = top_missing_values.head(10).reset_index()
top_10_missing.columns = ["Variable", "Cantidad de vacíos/nulos"]

# Calculate the percentage of missing values for each of the top 10 variables
total_rows = df.shape[0]
top_10_missing["Porcentaje"] = (top_10_missing["Cantidad de vacíos/nulos"] / total_rows * 100).round(2)

# Display the table
display(top_10_missing)
# Out:
#                   Variable  Cantidad de vacíos/nulos  Porcentaje
# 0      Obs_tiemp_obtención                     73710       92.09
# 1     URL_TRAMITE_EN_LINEA                     72149       90.14
# 2    Fecha Llegada al DAFP                     21492       26.85
# 3  Fecha Asignación asesor                     20953       26.18
# 4        Fecha Sin Gestión                     15755       19.68
# 5        Fecha En Creación                      6196        7.74
# 6                   Sector                       701        0.88
# 7                Categoría                        84        0.10
# 8           Número trámite                         2        0.00
# 9          Fecha Publicado                         2        0.00

# %%
# ✅ Diagnóstico completo del contenido original
total_registros = df.shape[0]
nulos = df["URL_TRAMITE_EN_LINEA"].isna().sum()
vacios = df["URL_TRAMITE_EN_LINEA"].apply(lambda x: isinstance(x, str) and x.strip() == "").sum()
no_strings = df["URL_TRAMITE_EN_LINEA"].apply(lambda x: not isinstance(x, str) and pd.notna(x)).sum()

print("🔍 Diagnóstico de la columna 'URL_TRAMITE_EN_LINEA'")
print(f"📄 Total de filas en el archivo: {total_registros}")
print(f"🚫 Valores nulos: {nulos}")
print(f"🚫 Strings vacíos o solo espacios: {vacios}")
print(f"🚫 Celdas con tipo distinto a string (por ejemplo, número): {no_strings}")

# ✅ Filtrar solo URLs válidas (sin quitar duplicados)
urls = df["URL_TRAMITE_EN_LINEA"].dropna()
urls = [u for u in urls if isinstance(u, str) and u.strip() != ""]

# ✅ Guardar todas las URLs válidas (incluso duplicadas) en archivo de texto
with open("urls.txt", "w") as f:
    f.write("\n".join(urls))

print(f"\n✅ Se guardaron {len(urls)} URLs válidas (con duplicados) en 'urls.txt'")
# Out:
# 🔍 Diagnóstico de la columna 'URL_TRAMITE_EN_LINEA'
# 📄 Total de filas en el archivo: 80044
# 🚫 Valores nulos: 72149
# 🚫 Strings vacíos o solo espacios: 0
# 🚫 Celdas con tipo distinto a string (por ejemplo, número): 0
#
# ✅ Se guardaron 7895 URLs válidas (con duplicados) en 'urls.txt'

# %% [markdown]
# ###**4.1 Distribución de URLs Únicas y Duplicadas**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Get the URLs from the specified column, drop NaNs and empty strings
urls_column = df["URL_TRAMITE_EN_LINEA"].dropna()
urls_column = urls_column[urls_column != ""]

# Calculate unique and duplicate counts
total_urls = len(urls_column)
unique_urls = urls_column.nunique()
duplicate_urls = total_urls - unique_urls

# Create a DataFrame for plotting
data = {'Category': ['Únicas', 'Duplicadas'],
        'Count': [unique_urls, duplicate_urls]}
df_counts = pd.DataFrame(data)

# Create the pie chart
plt.figure(figsize=(6, 6))
plt.pie(df_counts['Count'], labels=df_counts['Category'], autopct='%1.1f%%',
        startangle=90, colors=sns.color_palette('viridis', len(df_counts)))
plt.title("Distribución de URLs Únicas y Duplicadas")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

print(f"Total de URLs válidas (incluyendo duplicados): {total_urls}")
print(f"URLs Únicas: {unique_urls}")
print(f"URLs Duplicadas: {duplicate_urls}")
# Out:
# Total de URLs válidas (incluyendo duplicados): 7895
# URLs Únicas: 3896
# URLs Duplicadas: 3999

# %% [markdown]
# ###**4.2 Top 10 del número y porcentaje de URLs duplicadas sobre el total**

# %%
# Get the URLs from the specified column, drop NaNs and empty strings
urls_column = df["URL_TRAMITE_EN_LINEA"].dropna()
urls_column = urls_column[urls_column != ""]

# Calculate the frequency of each URL
url_counts = urls_column.value_counts()

# Filter for duplicate URLs (count > 1)
duplicate_urls_counts = url_counts[url_counts > 1]

# Get the top 10 most frequent duplicate URLs
top_10_duplicates = duplicate_urls_counts.head(10).reset_index()
top_10_duplicates.columns = ["URL", "Conteo"]

# Calculate the percentage of each top 10 duplicate URL out of the total valid URLs (8650)
total_valid_urls = 8650
top_10_duplicates["Porcentaje"] = (top_10_duplicates["Conteo"] / total_valid_urls * 100).round(2)

# Display the table
display(top_10_duplicates)
# Out:
#                                                  URL  Conteo  Porcentaje
# 0  http://sac2.gestionsecretariasdeeducacion.gov....      98        1.13
# 1             https://portalciudadano.sisben.gov.co/      89        1.03
# 2  http://vital.minambiente.gov.co/SILPA/TestSilp...      67        0.77
# 3            https://www.ventanillamovilidad.com.co/      50        0.58
# 4  https://www.marmato-caldas.gov.co/peticiones-q...      42        0.49
# 5  https://digital.movilidadpereira.gov.co/portal...      41        0.47
# 6                    https://infoconsumo.syc.com.co/      39        0.45
# 7  https://mercurio.antioquia.gov.co/mercurio/Ser...      35        0.40
# 8  https://movilidad.alcaldiafusagasuga.gov.co/tr...      33        0.38
# 9    https://sedeelectronica.supervigilancia.gov.co/      33        0.38

# %% [markdown]
# ###**✅ 5. Ejecutar el validador**

# %%
# %cd /content/advanced-url-checker
# Out:
# /content/advanced-url-checker

# %%
import os
os.makedirs("log", exist_ok=True)

# %%
# !python endpoint_checker.py urls.txt -o resultados.csv --threads 30
# Out:
# 2025-08-07 06:03:12,813 - WARNING - Blocked private IP: http://172.20.3.189:8280/consultaCedulas/public/consultarCertificadoEstadoPPT.jsf
# 2025-08-07 06:03:12,813 - WARNING - Invalid URL on line 132: http://172.20.3.189:8280/consultaCedulas/public/consultarCertificadoEstadoPPT.jsf
# 2025-08-07 06:03:12,820 - WARNING - Invalid URL on line 211: http://www.reincorporacion.gov.co/es/agencia/Paginas/maestro-de-documentos.aspx?Paged=TRUE&p_ProcesoSIGER=Implementaci%c3%b3n&p_TipoSIGER=Instructivo&p_ID=256407&PageFirstRow=451&&View
# 2025-08-07 06:03:12,821 - WARNING - Invalid URL on line 212: http://www.reincorporacion.gov.co/es/agencia/Paginas/maestro-de-documentos.aspx?Paged=TRUE&p_ProcesoSIGER=Implementaci%c3%b3n&p_TipoSIGER=Instructivo&p_ID=256407&PageFirstRow=451&&View
# 2025-08-07 06:03:12,821 - WARNING - Invalid URL on line 214: http://contacto@archivogeneral.gov.co;gt@archivogeneral.gov.co
# 2025-08-07 06:03:12,821 - WARNING - Invalid URL on line 215: http://servicioalpublico@archivogeneral.gov.co;gt@archivogeneral.gov.co
# Active: 541 | Inactive: 14 | Errors: 111:   9%|█▍               | 666/7750 [00:55<06:40, 17.71url/s]2025-08-07 06:04:08,840 - WARNING - Failed to parse headers (url=https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/DMSWebFormExit): [MissingHeaderBodySeparatorDefect()], unparsed data: 'Permissions-Policy : geolocation=(self "https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/Agora/"), microphone=()\r\nReferrer-Policy : strict-origin\r\nStrict-Transport-Security : max-age=31536000; includeSubDomains; preload\r\nX-Content-Type-Options : nosniff\r\nX-frame-Options: SAMEORIGIN\r\nX-XSS-Protection: 1; mode=block\r\nDate: Thu, 07 Aug 2025 06:04:08 GMT\r\nContent-Length: 198\r\nSet-Cookie: NSC_ESNS=02970530-41d8-1894-9678-0050568afedc_1391408851_0801985132_00000000000042790374; Path=/; Expires=Thu, 07-Aug-2025 06:04:23 GMT\r\n\r\n'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/connection.py", line 568, in getresponse
#     assert_header_parsing(httplib_response.msg)
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/util/response.py", line 88, in assert_header_parsing
#     raise HeaderParsingError(defects=defects, unparsed_data=unparsed_data)
# urllib3.exceptions.HeaderParsingError: [MissingHeaderBodySeparatorDefect()], unparsed data: 'Permissions-Policy : geolocation=(self "https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/Agora/"), microphone=()\r\nReferrer-Policy : strict-origin\r\nStrict-Transport-Security : max-age=31536000; includeSubDomains; preload\r\nX-Content-Type-Options : nosniff\r\nX-frame-Options: SAMEORIGIN\r\nX-XSS-Protection: 1; mode=block\r\nDate: Thu, 07 Aug 2025 06:04:08 GMT\r\nContent-Length: 198\r\nSet-Cookie: NSC_ESNS=02970530-41d8-1894-9678-0050568afedc_1391408851_0801985132_00000000000042790374; Path=/; Expires=Thu, 07-Aug-2025 06:04:23 GMT\r\n\r\n'
# Active: 626 | Inactive: 31 | Errors: 123:  10%|█▋               | 780/7750 [01:06<12:26,  9.33url/s]2025-08-07 06:04:20,072 - WARNING - Failed to parse headers (url=https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/DMSWebFormExit): [MissingHeaderBodySeparatorDefect()], unparsed data: 'Permissions-Policy : geolocation=(self "https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/Agora/"), microphone=()\r\nReferrer-Policy : strict-origin\r\nStrict-Transport-Security : max-age=31536000\r\nX-Content-Type-Options : nosniff\r\nX-frame-Options: SAMEORIGIN\r\nX-XSS-Protection: 1; mode=block\r\nDate: Thu, 07 Aug 2025 06:04:19 GMT\r\nContent-Length: 1245\r\nSet-Cookie: NSC_ESNS=029a9030-41e3-1894-9678-0050568afedc_3825546963_2569491052_00000000000042790388; Path=/; Expires=Thu, 07-Aug-2025 06:04:34 GMT\r\n\r\n'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/connection.py", line 568, in getresponse
#     assert_header_parsing(httplib_response.msg)
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/util/response.py", line 88, in assert_header_parsing
#     raise HeaderParsingError(defects=defects, unparsed_data=unparsed_data)
# urllib3.exceptions.HeaderParsingError: [MissingHeaderBodySeparatorDefect()], unparsed data: 'Permissions-Policy : geolocation=(self "https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/Agora/"), microphone=()\r\nReferrer-Policy : strict-origin\r\nStrict-Transport-Security : max-age=31536000\r\nX-Content-Type-Options : nosniff\r\nX-frame-Options: SAMEORIGIN\r\nX-XSS-Protection: 1; mode=block\r\nDate: Thu, 07 Aug 2025 06:04:19 GMT\r\nContent-Length: 1245\r\nSet-Cookie: NSC_ESNS=029a9030-41e3-1894-9678-0050568afedc_3825546963_2569491052_00000000000042790388; Path=/; Expires=Thu, 07-Aug-2025 06:04:34 GMT\r\n\r\n'
# Active: 647 | Inactive: 31 | Errors: 132:  10%|█▊               | 810/7750 [01:08<04:56, 23.37url/s]2025-08-07 06:04:21,632 - WARNING - Failed to parse headers (url=https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/DMSWebFormExit): [MissingHeaderBodySeparatorDefect()], unparsed data: 'Permissions-Policy : geolocation=(self "https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/Agora/"), microphone=()\r\nReferrer-Policy : strict-origin\r\nStrict-Transport-Security : max-age=31536000\r\nX-Content-Type-Options : nosniff\r\nX-XSS-Protection: 1; mode=block\r\nX-frame-Options: SAMEORIGIN\r\nDate: Thu, 07 Aug 2025 06:04:21 GMT\r\nContent-Length: 1245\r\nSet-Cookie: NSC_ESNS=029358ed-41e5-1894-9678-0050568afedc_3896981203_2506445420_00000000000042790390; Path=/; Expires=Thu, 07-Aug-2025 06:04:36 GMT\r\n\r\n'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/connection.py", line 568, in getresponse
#     assert_header_parsing(httplib_response.msg)
#   File "/usr/local/lib/python3.11/dist-packages/urllib3/util/response.py", line 88, in assert_header_parsing
#     raise HeaderParsingError(defects=defects, unparsed_data=unparsed_data)
# urllib3.exceptions.HeaderParsingError: [MissingHeaderBodySeparatorDefect()], unparsed data: 'Permissions-Policy : geolocation=(self "https://fiduprevisorafidugestor.digitalwaresaas.com.co:8082/Agora/"), microphone=()\r\nReferrer-Policy : strict-origin\r\nStrict-Transport-Security : max-age=31536000\r\nX-Content-Type-Options : nosniff\r\nX-XSS-Protection: 1; mode=block\r\nX-frame-Options: SAMEORIGIN\r\nDate: Thu, 07 Aug 2025 06:04:21 GMT\r\nContent-Length: 1245\r\nSet-Cookie: NSC_ESNS=029358ed-41e5-1894-9678-0050568afedc_3896981203_2506445420_00000000000042790390; Path=/; Expires=Thu, 07-Aug-2025 06:04:36 GMT\r\n\r\n'
# Active: 1130 | Inactive: 80 | Errors: 442:  21%|███▏           | 1652/7750 [03:00<02:10, 46.56url/s]2025-08-07 06:06:13,766 - WARNING - Blocked redirect to invalid URL: http://admisiones.upn.edu.co2021/07/26/registro-de-espacios-academicos-estudiantes-nuevos-2021-2/
# Active: 1193 | Inactive: 86 | Errors: 449:  22%|███▎           | 1728/7750 [03:07<09:31, 10.54url/s]2025-08-07 06:06:21,069 - WARNING - Blocked redirect to invalid URL: https://acacias-meta.softwaretributario.com/portalv2017/impuestos.portal.wpnbienvenidoipu.aspx?IPU
# Active: 2864 | Inactive: 184 | Errors: 723:  49%|██████▊       | 3771/7750 [05:46<03:36, 18.38url/s]2025-08-07 06:09:00,403 - WARNING - Blocked redirect to invalid URL: http://puertoboyaca-boyaca.softwaretributario.com/impuestos.portal.wpnbienvenidoipu.aspx?IPU
# Active: 5438 | Inactive: 497 | Errors: 1149:  91%|███████████▉ | 7084/7750 [11:18<00:27, 24.09url/s]2025-08-07 06:14:32,155 - WARNING - Blocked redirect to invalid URL: https://uxxilogin.elpoli.edu.co:443/oam/server/obrareq.cgi?encquery%3DKtYb5y27wzq1nspY%2BCDTQLDbnfLrDm14LtIBtdEpXjv0jTS5hZmGN06n2BHG1skG7Tf7hBW5PiW4tF17pJ8a1IA3KUrVCDYV3%2FQl5lNQD1ipZn2dYschohSjgndVpTxy6cvJ1Hw%2B8ObfScKZ2OQ7qKnR2c9H6Moupd%2BrKLzuIIGsN4sV1Ls43wfYE6jgRGqrG6AoEz56k9U8URym6eK2mM38XpAlpEqdquDuQFcJH%2FtadOb8XIhdkDZ4IIeIj989lwN5fK2m9WnF%2F4NXD9927xj3MMjvU%2B9OTitzJm2IMccf7L7VzGwodSwSjsZFReFI%20agentid%3DWT2_produccion%20ver%3D1%20crmethod%3D2%26cksum%3Db18685ee50c701d26724c2d193db6d3d013bfa05&ECID-Context=1.006Ew1Ut5W7DwWC5zF%5EAyW00043500FS6_%3BkXjE
# Active: 5889 | Inactive: 569 | Errors: 1292: 100%|█████████████| 7750/7750 [12:24<00:00, 10.41url/s]
#
# ============================================================
# SUMMARY
# ============================================================
#
# Total URLs processed: 7750
# Active URLs: 5889 (76.0%)
# Inactive URLs: 569 (7.3%)
# Timeouts: 470
# DNS Errors: 102
# Connection Errors: 646
# SSL Errors: 0
# Other Errors: 74
#
# Processing Time: 744.5s
# Processing Rate: 10.4 URLs/s
#
# Output Files:
# - Main results: resultados.csv
# - Active URLs: resultados.csv_active.txt
# - Inactive URLs: resultados.csv_inactive.txt
# - Log file: resultados.csv.log
#
# 2025-08-07 06:15:37,863 - INFO - Processing completed

# %% [markdown]
# ###**✅ Paso 6: Convertir resultados.csv en un DataFrame estructurado**

# %%
import pandas as pd
import re

# Leer las líneas
with open("/content/advanced-url-checker/resultados.csv", "r", encoding="utf-8") as f:
    lines = f.readlines()

data = []

# Parsear cada línea
for line in lines:
    line = line.strip()

    # Línea con error
    if "ERROR" in line:
        match = re.match(r"^(.*?): ERROR \[([\d.]+)\] - (.*)", line)
        if match:
            url, tiempo, mensaje_error = match.groups()
            data.append({
                "url": url,
                "estado": "ERROR",
                "codigo_http": None,
                "tiempo_respuesta": float(tiempo),
                "mensaje_error": mensaje_error
            })
        continue

    # Línea válida con código HTTP
    match = re.match(r"^(.*?): (\w+) \(HTTP (\d+)\) \[([\d.]+)\]$", line)
    if match:
        url, estado, codigo, tiempo = match.groups()
        data.append({
            "url": url,
            "estado": estado,
            "codigo_http": int(codigo),
            "tiempo_respuesta": float(tiempo),
            "mensaje_error": None
        })

# Crear DataFrame
df_resultados = pd.DataFrame(data)
df_resultados.head()
# Out:
#                                                  url  estado  codigo_http  \
# 0  https://www.gov.co/tramites-y-servicios/dps/co...  ACTIVE        200.0
# 1                         https://simo4.cnsc.gov.co/  ACTIVE        200.0
# 2                         https://simo4.cnsc.gov.co/  ACTIVE        200.0
# 3                         https://simo4.cnsc.gov.co/  ACTIVE        200.0
# 4  https://afiliaciones.fna.gov.co:8051/afiliacio...  ACTIVE        200.0
#
#    tiempo_respuesta mensaje_error
# 0             0.124          None
# 1             0.474          None
# 2             0.473          None
# 3             0.478          None
# 4             0.539          None

# %% [markdown]
# ###**✅ Paso 7: Detectar si redirige al home del dominio**

# %%
from urllib.parse import urlparse

def redirige_a_home(row):
    try:
        parsed = urlparse(row["url"])
        if parsed.path not in ["", "/"]:
            return parsed.netloc + "/"
        else:
            return None
    except:
        return None

df_resultados["redirige_al_home"] = df_resultados.apply(redirige_a_home, axis=1)

# %% [markdown]
# ###**✅ Paso 8: Clasificar las URLs**
# Crea una columna clasificacion con valores:
#
# *   "FUNCIONA"
# *   "ROTO"
# *   "REDIRECCIONA AL HOME"
# *   "SIN CLASIFICAR"

# %%
def clasificar_url(row):
    if row["estado"] == "ERROR":
        return "ROTO"
    if row["codigo_http"] and row["codigo_http"] >= 400:
        return "ROTO"
    if row["redirige_al_home"]:
        return "REDIRECCIONA AL HOME"
    if row["codigo_http"] and 200 <= row["codigo_http"] < 400:
        return "FUNCIONA"
    return "SIN CLASIFICAR"

df_resultados["clasificacion"] = df_resultados.apply(clasificar_url, axis=1)

# %% [markdown]
# ###**✅ Paso 9: Generar tabla resumen para informe**

# %%
# Conteo total por categoría
resumen = df_resultados["clasificacion"].value_counts().reset_index()
resumen.columns = ["clasificacion", "cantidad"]

# Calcular porcentaje
total = resumen["cantidad"].sum()
resumen["porcentaje"] = (resumen["cantidad"] / total * 100).round(2)

resumen
# Out:
#           clasificacion  cantidad  porcentaje
# 0  REDIRECCIONA AL HOME      4612       63.35
# 1                  ROTO      1391       19.11
# 2              FUNCIONA      1277       17.54

# %% [markdown]
# ###**✅ Paso 10: Exportar resultados completos a Excel**

# %%
df_resultados.to_excel("resultados_clasificados.xlsx", index=False)

from google.colab import files
files.download("resultados_clasificados.xlsx")

# %% [markdown]
# ### **✅ 9.1. Gráfico de Barras Horizontales**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# 🔇 Ocultar advertencias tipo FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning)

# Ordenar por cantidad
resumen_sorted = resumen.sort_values(by="cantidad", ascending=False)

# Crear gráfico de barras horizontal
plt.figure(figsize=(6, 3))
ax = sns.barplot(x="cantidad", y="clasificacion", data=resumen_sorted, palette="viridis")

# Etiquetas en las barras
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=3)

plt.xlabel("Cantidad")
plt.ylabel("Clasificación")
plt.title("Distribución de URLs por Clasificación (Gráfico de Barras)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **✅ 9.2. Gráfico de Torta**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the resumen DataFrame by count in descending order
resumen_sorted = resumen.sort_values(by="cantidad", ascending=False)

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(resumen_sorted["cantidad"], labels=resumen_sorted["clasificacion"],
autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis', len(resumen_sorted)))
plt.title("Distribución de URLs por Clasificación (Gráfico de Torta)")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ###**🧩 Resumen del Gráfico y Hallazgos**
#
# *  63.4% de los enlaces analizados redirigen al inicio del portal (home) en lugar de llevar al trámite o servicio específico.
#
# *  19.1% están rotos (no funcionan).
#
# *  Solo 17.5% funcionan correctamente y llevan al contenido esperado.
#
# **🧬 ¿Por qué ocurre esto?**
#
# - Muchos portales del distrito, como el de la Alcaldía de Bogotá, usan tecnologías modernas (como Liferay) que cargan contenido sin cambiar completamente la dirección del sitio. Por eso:
#
# - Aunque el ciudadano navega internamente, al copiar el enlace este no lleva al mismo lugar, sino al inicio del portal.
#
# - Esto se conoce como una aplicación de página única (SPA), y requiere una configuración especial para que los enlaces sean reutilizables.
#
# **📌 ¿Por qué es importante?**
#
# - Afecta la experiencia del ciudadano.
#
# - Reduce la efectividad de las estrategias de servicios digitales.
#
# - Complica el acceso real a trámites, especialmente desde plataformas como el SUIT o redes sociales.
#
# **✅ Recomendaciones**
# - Auditar periódicamente los enlaces públicos.
#
# - Configurar los portales para que los enlaces sean compartibles y reutilizables.
#
# - Coordinar entre tecnología y comunicaciones para mejorar el acceso real a los servicios digitales.

# %% [markdown]
# ### **✅ 10. Tabla del top 10 de enlaces rotos**

# %%
import pandas as pd
from IPython.display import display, HTML

# Filtrar el DataFrame de resultados para URLs con clasificación 'ROTO'
roto_urls_df = df_resultados[df_resultados['clasificacion'] == 'ROTO'].copy()

# Encontrar URLs duplicadas dentro del estado 'ROTO'
# duplicated(keep=False) marca todas las ocurrencias de un duplicado como True
duplicated_roto_urls = roto_urls_df[roto_urls_df.duplicated(subset=['url'], keep=False)]

# Contar las ocurrencias de cada URL duplicada en estado 'ROTO'
duplicated_roto_counts = duplicated_roto_urls['url'].value_counts()

# Obtener el top 10 de las URLs duplicadas en estado 'ROTO' más frecuentes
top_10_roto_duplicates_counts = duplicated_roto_counts.head(10).reset_index()
top_10_roto_duplicates_counts.columns = ["URL", "Conteo"]

# Opcional: Obtener información adicional de estas URLs del DataFrame original roto_urls_df
# Esto puede ser útil si necesitas otras columnas además de la URL y el conteo
# top_10_roto_duplicates_info = roto_urls_df[roto_urls_df['url'].isin(top_10_roto_duplicates_counts['URL'])].drop_duplicates(subset=['url'])
# top_10_final = pd.merge(top_10_roto_duplicates_counts, top_10_roto_duplicates_info[['url', 'codigo_http', 'mensaje_error']], on='URL', how='left')


# Formatear las URLs como enlaces HTML
def make_clickable(url):
    return f'<a href="{url}" target="_blank">{url}</a>'

# Aplicar el formato a la columna 'URL'
top_10_roto_duplicates_counts['URL'] = top_10_roto_duplicates_counts['URL'].apply(make_clickable)


# Mostrar la tabla como HTML para que los enlaces sean clickeables
# Se usa .to_html() para renderizar el DataFrame como HTML
display(HTML(top_10_roto_duplicates_counts.to_html(escape=False))) # escape=False permite que se renderice el HTML
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>URL</th>
#       <th>Conteo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="https://serviciosdigitales.movilidadavanzadabello.com.co/portal-servicios/#/public" target="_blank">https://serviciosdigitales.movilidadavanzadabello.com.co/portal-servicios/#/public</a></td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="https://gestdoc.barranquilla.gov.co/RadicacionSolicitudes/" target="_blank">https://gestdoc.barranquilla.gov.co/RadicacionSolicitudes/</a></td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="http://contactenos@madridcundinamarca.gov.co" target="_blank">http://contactenos@madridcundinamarca.gov.co</a></td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="http://gestdoc.barranquilla.gov.co:83/RadicacionSolicitudes/" target="_blank">http://gestdoc.barranquilla.gov.co:83/RadicacionSolicitudes/</a></td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="https://www.cartago.gov.co/quejas-y-reclamos/" target="_blank">https://www.cartago.gov.co/quejas-y-reclamos/</a></td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="https://www.integracionsocial.gov.co/index.php/atencion-ciudadana/puntos-atencion" target="_blank">https://www.integracionsocial.gov.co/index.php/atencion-ciudadana/puntos-atencion</a></td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="https://www.aerocivil.gov.co/atencion/informaci%C3%B3n/tr%C3%A1mites-y-servicios" target="_blank">https://www.aerocivil.gov.co/atencion/informaci%C3%B3n/tr%C3%A1mites-y-servicios</a></td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="https://www.metropol.gov.co/tramitesenlinea" target="_blank">https://www.metropol.gov.co/tramitesenlinea</a></td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="https://www.secretariadeambiente.gov.co/ventanillavirtual/app" target="_blank">https://www.secretariadeambiente.gov.co/ventanillavirtual/app</a></td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="https://sgi.caldas.gov.co/sgi/secciones/tramites/diligenciarTramite.php?instance=6776649b4a1c7e3518b9f3551987a132&tipoId=62&token=db92adc08482e068f4a38df700cfc665" target="_blank">https://sgi.caldas.gov.co/sgi/secciones/tramites/diligenciarTramite.php?instance=6776649b4a1c7e3518b9f3551987a132&tipoId=62&token=db92adc08482e068f4a38df700cfc665</a></td>
#       <td>13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **✅ 11. Tabla del top 10 de enlaces que redireccionan al home (REVISAR)**

# %%
import pandas as pd
from IPython.display import display, HTML

# Filtrar el DataFrame de resultados para URLs con clasificación 'REDIRECCIONA AL HOME'
redirige_urls_df = df_resultados[df_resultados['clasificacion'] == 'REDIRECCIONA AL HOME'].copy()

# Encontrar URLs duplicadas dentro del estado 'REDIRECCIONA AL HOME'
# duplicated(keep=False) marca todas las ocurrencias de un duplicado como True
duplicated_redirige_urls = redirige_urls_df[redirige_urls_df.duplicated(subset=['url'], keep=False)]

# Contar las ocurrencias de cada URL duplicada en estado 'REDIRECCIONA AL HOME'
duplicated_redirige_counts = duplicated_redirige_urls['url'].value_counts().reset_index()
duplicated_redirige_counts.columns = ["URL", "Conteo"]

# Obtener el top 10 de las URLs duplicadas en estado 'REDIRECCIONA AL HOME' más frecuentes
top_10_redirige_duplicates_counts = duplicated_redirige_counts.head(10)

# Opcional: Fusionar con el DataFrame original (df) para obtener el 'Nombre del trámite'
# Se realiza un merge para obtener la información del trámite para cada URL
# Se usa 'left' merge para mantener todas las filas del top_10_redirige_duplicates_counts
# Se eliminan duplicados en la columna 'URL_TRAMITE_EN_LINEA' del dataframe original para evitar filas excesivas
df_unique_urls = df.drop_duplicates(subset=['URL_TRAMITE_EN_LINEA'])
top_10_with_nombre_redirige = pd.merge(top_10_redirige_duplicates_counts, df_unique_urls[['URL_TRAMITE_EN_LINEA', 'Nombre del trámite']],
                              left_on='URL', right_on='URL_TRAMITE_EN_LINEA', how='left')

# Eliminar la columna duplicada 'URL_TRAMITE_EN_LINEA' si existe
top_10_with_nombre_redirige = top_10_with_nombre_redirige.drop(columns=['URL_TRAMITE_EN_LINEA'])


# Formatear las URLs como enlaces HTML
def make_clickable(url):
    return f'<a href="{url}" target="_blank">{url}</a>'

# Aplicar el formato a la columna 'URL'
top_10_with_nombre_redirige['URL'] = top_10_with_nombre_redirige['URL'].apply(make_clickable)

# Reordenar columnas para que 'Nombre del trámite' aparezca primero
top_10_final_redirige = top_10_with_nombre_redirige[['Nombre del trámite', 'URL', 'Conteo']]

# Mostrar la tabla como HTML para que los enlaces sean clickeables
# Se usa .to_html() para renderizar el DataFrame como HTML
display(HTML(top_10_final_redirige.to_html(escape=False))) # escape=False permite que se renderice el HTML
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nombre del trámite</th>
#       <th>URL</th>
#       <th>Conteo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Actualización información en la base de datos del sistema de identificación y clasificación de potenciales beneficiarios de programas sociales – SISBEN</td>
#       <td><a href="http://sac2.gestionsecretariasdeeducacion.gov.co/app_Login/?sec=104" target="_blank">http://sac2.gestionsecretariasdeeducacion.gov.co/app_Login/?sec=104</a></td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Acreditación o Certificación de las inversiones realizadas en control, conservación y mejoramiento del medio ambiente para obtener descuento en el impuesto sobre la renta</td>
#       <td><a href="http://vital.minambiente.gov.co/SILPA/TestSilpa/security/login.aspx" target="_blank">http://vital.minambiente.gov.co/SILPA/TestSilpa/security/login.aspx</a></td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Aprobación de los planos de propiedad horizontal</td>
#       <td><a href="https://www.marmato-caldas.gov.co/peticiones-quejas-reclamos" target="_blank">https://www.marmato-caldas.gov.co/peticiones-quejas-reclamos</a></td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Cambio de carrocería de un vehículo automotor</td>
#       <td><a href="https://digital.movilidadpereira.gov.co/portal-servicios/#/agendar-cita-publica" target="_blank">https://digital.movilidadpereira.gov.co/portal-servicios/#/agendar-cita-publica</a></td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Blindaje de un vehículo automotor</td>
#       <td><a href="https://movilidad.alcaldiafusagasuga.gov.co/tramites/" target="_blank">https://movilidad.alcaldiafusagasuga.gov.co/tramites/</a></td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Auxilio_Funerario</td>
#       <td><a href="https://sedeelectronica.ugpp.gov.co/SedeElectronica/tramites/browser.do#no-back-button" target="_blank">https://sedeelectronica.ugpp.gov.co/SedeElectronica/tramites/browser.do#no-back-button</a></td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Actas orgánicas y estatutos de fondos mutuos de inversión</td>
#       <td><a href="https://wl.superfinanciera.gov.co/SiriWeb/" target="_blank">https://wl.superfinanciera.gov.co/SiriWeb/</a></td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Autorización de calendario académico especial</td>
#       <td><a href="http://sac2.gestionsecretariasdeeducacion.gov.co/app_Login/" target="_blank">http://sac2.gestionsecretariasdeeducacion.gov.co/app_Login/</a></td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Acreditación o Certificación de las inversiones realizadas en control, conservación y mejoramiento del medio ambiente para obtener descuento en el impuesto sobre la renta</td>
#       <td><a href="http://vital.minambiente.gov.co/SILPA/TESTSILPA/Security/Login.aspx" target="_blank">http://vital.minambiente.gov.co/SILPA/TESTSILPA/Security/Login.aspx</a></td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Cambio de carrocería de un vehículo automotor</td>
#       <td><a href="https://serviciosdetransitodigitales.com/portal-servicios/#/agendar-cita-publica" target="_blank">https://serviciosdetransitodigitales.com/portal-servicios/#/agendar-cita-publica</a></td>
#       <td>28</td>
#     </tr>
#   </tbody>
# </table>
